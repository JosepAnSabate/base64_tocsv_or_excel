# %%
import geopandas as gpd
import pandas as pd
import io
import base64

# %%
csv_in_base64 = '...'

# %%
file_content=base64.b64decode(csv_in_base64)

# %%
toread = io.BytesIO()
toread.write(file_content)
# Out:
# 9455

# %%
toread

# %%
toread.seek(0)
# Out:
# 0

# %%
df = pd.read_csv(toread)

# %%
df.head(1)
# Out:
#   country       lat.     long.     name
# 0      AD  42.546245  1.601554  Andorra

# %%
excel_in_base64 = '...'

# %%
file_content_ex=base64.b64decode(excel_in_base64)

# %%
toread_ex = io.BytesIO()
toread_ex.write(file_content_ex)
# Out:
# 16019

# %%
toread_ex

# %%
toread_ex.seek(0)
# Out:
# 0

# %%
import openpyxl

# %%
df_ex = pd.read_excel(toread_ex, engine='openpyxl')

# %%
df_ex
# Out:
#      Unnamed: 0 country   latitude  longitude                  name
# 0             0      AD  42.546245   1.601554               Andorra
# 1             1      AE  23.424076  53.847818  United Arab Emirates
# 2             2      AF  33.939110  67.709953           Afghanistan
# 3             3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4             4      AI  18.220554 -63.068615              Anguilla
# ..          ...     ...        ...        ...                   ...
# 240         240      YE  15.552727  48.516388                 Yemen
# 241         241      YT -12.827500  45.166244               Mayotte
# 242         242      ZA -30.559482  22.937506          South Africa
# 243         243      ZM -13.133897  27.849332                Zambia
# 244         244      ZW -19.015438  29.154857              Zimbabwe
#
# [245 rows x 5 columns]
